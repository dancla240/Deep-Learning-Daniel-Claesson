# %%
import keras
import tensorflow as tf
import gymnasium as gym
import ale_py
from gymnasium . wrappers . frame_stack import FrameStack
from gymnasium . wrappers . atari_preprocessing import AtariPreprocessing
gym.register_envs (ale_py)

# %%
model_file = r'C:/Users/danie/Google Drive/GoogleColab/BreakOut_01/breakout_model_2804.keras'
agent = keras.models.load_model(model_file, compile=False, safe_mode=False)

env = gym.make("BreakoutNoFrameskip-v4", render_mode="human")
env = AtariPreprocessing(env)
env = FrameStack(env, 4)

state, _ = env.reset()
done = False

while not done:
    # first convert to a tensor for compute efficiency
    state_tensor = tf.convert_to_tensor(state)
    # shape of state is 4, 84, 84, but we need 84, 84, 4
    state_tensor = tf.transpose(state_tensor, [1, 2, 0])
    # Add batch dimension
    state_tensor = tf.expand_dims(state_tensor, 0)
    # ’predict ’ method is for large batches , call as function instead
    action_probs = agent(state_tensor, training=False)
    # Take ’best ’ action
    action = tf.argmax(action_probs[0]).numpy()

    state, reward, done, _, _ = env.step(action)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 model_file = r'C:/Users/danie/Google Drive/GoogleColab/BreakOut_01/breakout_model_2804.keras'
# ----> 2 agent = keras.models.load_model(model_file, compile=False, safe_mode=False)
#       4 env = gym.make("BreakoutNoFrameskip-v4", render_mode="human")
#       5 env = AtariPreprocessing(env)
#
# File c:\Users\danie\Documents\GitHub\Deep-Learning-Daniel-Claesson\.venv\Lib\site-packages\keras\src\saving\saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     186         is_keras_zip = True
#     188 if is_keras_zip or is_keras_dir or is_hf:
# --> 189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
# ...
